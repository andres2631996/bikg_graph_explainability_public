# %% [markdown]
# # Tutorial on a toy example
#
# We will design a graph with two communities influencing the behavior of a central node in a Graph Neural Network on a node prediction use case.
#
# The tutorial is divided into two cases:
#
# a) All the nodes in one of the communities have labels of almost 1 (0.9), and the nodes in the other community
# have labels of almost 0 (0.1). The central node is assigned a label of 0.9, and we show how the community with the nodes labelled as 0.9 is the most relevant for the value of 0.9 in the central node, according to XP-GNN.
#
# b) We complete the same use case as in a), but now "flipping" the labels. The community with low values of 0.9 in a) now has values of 0.1, and viceversa. In this case, we show how the other community is appointed as the most relevant one for
# the Graph Neural Network explanation, according to XP-GNN.
#
#
# # This experiment is a replica of the Experiment in Section 5.1 of "Community explanations in knowledge graphs with XP-GNN", by Andrés Martínez Mora, Dimitris Polychronopoulos, Michaël Ughetto, and Sebastian Nilsson

# %% [markdown]
# # Import libraries for analysis

# %%
import pandas as pd
import os,sys
import numpy as np
import networkx
import torch
from torch import nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv,Linear
from sklearn.metrics import r2_score
from torch_geometric.data import Data
import time
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from pathway_explanations.explainer import Explainer, set_seed

# %%
# Set random seed
seed = 1
set_seed(seed)

# %% [markdown]
# # Set up graph data

# %%
# Define device where to complete computations
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Setup edge index
edge_index = torch.tensor([[0,1],[1,0],[1,2],[2,1],[1,3],[3,1],[1,4],[4,1]],dtype=torch.long,
                              device=device)
edge_index = edge_index.T

# Set up community weights and community structure
communities = [[0],[2,3,4]]
community_names = ["blue","red"]

# Set node features as normally distributed
length = 16 # Feature size
features = torch.randn(int(torch.max(edge_index[0]).item())+1,
                       length, device=device)

node_names = ["{}".format(i) for i in range(features.shape[0])]

# Design training labels
Y = torch.tensor([0.1,0.9,0.9,0.9,0.9],dtype=torch.float,
                              device=device)

# Define train and test mask
# Central node is in the test set
test_size = 0.2
train_mask = torch.rand(Y.shape, device=device)
train_mask[train_mask < test_size] = 0
train_mask[train_mask > test_size] = 1
train_mask = train_mask.bool()
train_mask[1] = False # Keep node of interest in testing set
test_mask = ~train_mask

# %% [markdown]
# # Plot graph

# %%
edges_nx = [tuple(edge_index[:,i].cpu().numpy()) for i in range(edge_index.shape[-1])]
G = networkx.Graph()
G.add_edges_from(edges_nx)
colors = ["blue","black","red","red","red"]

plt.figure()
networkx.draw(G,node_color=colors,node_size=1000,with_labels=False)
plt.show()

# %% [markdown]
# # Model for training artificial graph

# %%
class GCN_homo(torch.nn.Module): # Homogeneous GCN
    def __init__(self, node_features):
        super().__init__()
        
        # Load hyperparameters
        seed = 0
        hidden_channels = 8
        out_neurons = 1
        conv_layers = [16, 8, 8]
        fc_layers = [8, 8, 16]

        seed,out_neurons = int(seed),int(out_neurons)
        
        torch.manual_seed(seed)
        
        conv_list,fc_list = [],[]
        
        for enum_conv_layer,conv_layer in enumerate(conv_layers): # Setup convolutional backbone
            assert isinstance(conv_layer,int) or isinstance(conv_layer,float),"Size of convolutional layer is not numeric"
            conv_layer = abs(int(conv_layer))
            
            if enum_conv_layer == 0:
                conv = GCNConv(node_features,conv_layer)
            else:
                conv = GCNConv(conv_layers[enum_conv_layer - 1],conv_layer)
                
            conv_list.append(conv)
            conv_list.append(nn.ReLU())
            
        self.conv = nn.ModuleList(conv_list)
        
        for enum_fc_layer,fc_layer in enumerate(fc_layers): # Setup linear backbone
        
            assert isinstance(fc_layer,int) or isinstance(fc_layer,float),"Size of convolutional layer is not numeric"
        
            if enum_fc_layer == (len(fc_layers) - 1): # Last FC layer
                lin = Linear(fc_layers[enum_fc_layer],out_neurons)
                act = nn.Sigmoid()
            else:
                lin = Linear(fc_layers[enum_fc_layer],fc_layers[enum_fc_layer + 1])
                act = nn.ReLU()
            fc_list.append(lin)
            fc_list.append(act)
            
        self.fc = nn.ModuleList(fc_list[:(-1)])
        #self.fc = nn.ModuleList(fc_list)
        
        
    def forward(self,x,edge_index):
        
        for enum_c,c in enumerate(self.conv): # Convolutional backbone
            if enum_c % 2 == 0: # Even layer: convolution
                x = c(x, edge_index)
            else: # Odd layer: activation function
                x = c(x)
                
        for l in self.fc: # Fully-connected backbone
            x = l(x)
        
        return x

# %% [markdown]
# # Model training

# %%
# Call architecture
model = GCN_homo(features.shape[-1]).to(device)
print(model)

# Load optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

model.train()

for epoch in range(500):
    optimizer.zero_grad()
    H = model(features, 
              edge_index)
    
    # Use MSE as loss for weight prediction
    loss = F.mse_loss(H.flatten(), 
                      Y.flatten())
    loss.backward()
    optimizer.step()
    
    r2_val = r2_score(Y[test_mask].cpu().detach().numpy(),
                      H[test_mask].cpu().detach().numpy())
    
    print("Epoch:", epoch+1, "// Train loss:", round(loss.item(),4),"// Validation R2:", round(r2_val,4)) 
    
    val_old = r2_val
# Out:
# GCN_homo(
#   (conv): ModuleList(
#     (0): GCNConv(16, 16)
#     (1): ReLU()
#     (2): GCNConv(16, 8)
#     (3): ReLU()
#     (4): GCNConv(8, 8)
#     (5): ReLU()
#   )
#   (fc): ModuleList(
#     (0): Linear(8, 8, bias=True)
#     (1): ReLU()
#     (2): Linear(8, 16, bias=True)
#     (3): ReLU()
#     (4): Linear(16, 1, bias=True)
#   )
# )
# Epoch: 1 // Train loss: 0.7256 // Validation R2: -3.2837
# Epoch: 2 // Train loss: 0.6629 // Validation R2: -2.9015
# Epoch: 3 // Train loss: 0.6078 // Validation R2: -2.5716
# Epoch: 4 // Train loss: 0.5582 // Validation R2: -2.2778
# Epoch: 5 // Train loss: 0.5214 // Validation R2: -2.0567
# Epoch: 6 // Train loss: 0.4919 // Validation R2: -1.8834
# Epoch: 7 // Train loss: 0.4661 // Validation R2: -1.7411
# Epoch: 8 // Train loss: 0.4397 // Validation R2: -1.5845
# Epoch: 9 // Train loss: 0.4167 // Validation R2: -1.4435
# Epoch: 10 // Train loss: 0.4006 // Validation R2: -1.3585
# Epoch: 11 // Train loss: 0.3864 // Validation R2: -1.2793
# Epoch: 12 // Train loss: 0.371 // Validation R2: -1.1906
# Epoch: 13 // Train loss: 0.3526 // Validation R2: -1.085
# Epoch: 14 // Train loss: 0.3323 // Validation R2: -0.977
# Epoch: 464 // Train loss: 0.0 // Validation R2: 0.9995
# Epoch: 465 // Train loss: 0.0 // Validation R2: 0.9996
# Epoch: 466 // Train loss: 0.0 // Validation R2: 0.9996
# Epoch: 467 // Train loss: 0.0 // Validation R2: 0.9996
# Epoch: 468 // Train loss: 0.0 // Validation R2: 0.9996
# Epoch: 469 // Train loss: 0.0 // Validation R2: 0.9996
# Epoch: 470 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 471 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 472 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 473 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 474 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 475 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 476 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 477 // Train loss: 0.0 // Validation R2: 0.9997
# Epoch: 478 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 479 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 480 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 481 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 482 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 483 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 484 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 485 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 486 // Train loss: 0.0 // Validation R2: 0.9998
# Epoch: 487 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 488 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 489 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 490 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 491 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 492 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 493 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 494 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 495 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 496 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 497 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 498 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 499 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 500 // Train loss: 0.0 // Validation R2: 0.9999

# %% [markdown]
# # Model training: case B

# %%
# Call architecture
modelB = GCN_homo(features.shape[-1]).to(device)
print(modelB)

# Load optimizer
optimizer = torch.optim.Adam(modelB.parameters(), lr=0.01)

modelB.train()

# Train until guaranteeing validation convergence
for epoch in range(500):
    optimizer.zero_grad()
    H = modelB(features, 
              edge_index)
    
    # Use MSE as loss for weight prediction
    loss = F.mse_loss(H.flatten(), 
                      Y_b.flatten())
    loss.backward()
    optimizer.step()
    
    r2_val = r2_score(Y_b[test_mask].cpu().detach().numpy(),
                      H[test_mask].cpu().detach().numpy())
    
    print("Epoch:", epoch+1, "// Train loss:", round(loss.item(),4),"// Validation R2:", round(r2_val,4)) 
    
    val_old = r2_val
# Out:
# GCN_homo(
#   (conv): ModuleList(
#     (0): GCNConv(16, 16)
#     (1): ReLU()
#     (2): GCNConv(16, 8)
#     (3): ReLU()
#     (4): GCNConv(8, 8)
#     (5): ReLU()
#   )
#   (fc): ModuleList(
#     (0): Linear(8, 8, bias=True)
#     (1): ReLU()
#     (2): Linear(8, 16, bias=True)
#     (3): ReLU()
#     (4): Linear(16, 1, bias=True)
#   )
# )
# Epoch: 1 // Train loss: 0.7256 // Validation R2: -3.2837
# Epoch: 2 // Train loss: 0.6629 // Validation R2: -2.9015
# Epoch: 3 // Train loss: 0.6078 // Validation R2: -2.5716
# Epoch: 4 // Train loss: 0.5582 // Validation R2: -2.2778
# Epoch: 5 // Train loss: 0.5214 // Validation R2: -2.0567
# Epoch: 6 // Train loss: 0.4919 // Validation R2: -1.8834
# Epoch: 7 // Train loss: 0.4661 // Validation R2: -1.7411
# Epoch: 8 // Train loss: 0.4397 // Validation R2: -1.5845
# Epoch: 9 // Train loss: 0.4167 // Validation R2: -1.4435
# Epoch: 10 // Train loss: 0.4006 // Validation R2: -1.3585
# Epoch: 11 // Train loss: 0.3864 // Validation R2: -1.2793
# Epoch: 12 // Train loss: 0.371 // Validation R2: -1.1906
# Epoch: 13 // Train loss: 0.3526 // Validation R2: -1.085
# Epoch: 14 // Train loss: 0.3323 // Validation R2: -0.977
# Epoch: 15 // Train loss: 0.3072 // Validation R2: -0.8384
# Epoch: 16 // Train loss: 0.2772 // Validation R2: -0.6708
# Epoch: 17 // Train loss: 0.2413 // Validation R2: -0.473
# Epoch: 18 // Train loss: 0.2003 // Validation R2: -0.2498
# Epoch: 19 // Train loss: 0.1564 // Validation R2: -0.0263
# Epoch: 20 // Train loss: 0.1157 // Validation R2: 0.1404
# Epoch: 21 // Train loss: 0.0903 // Validation R2: 0.154
# Epoch: 22 // Train loss: 0.0993 // Validation R2: -0.1293
# Epoch: 23 // Train loss: 0.1334 // Validation R2: -0.5448
# Epoch: 24 // Train loss: 0.1402 // Validation R2: -0.6178
# Epoch: 25 // Train loss: 0.1224 // Validation R2: -0.4221
# Epoch: 26 // Train loss: 0.1005 // Validation R2: -0.1631
# Epoch: 27 // Train loss: 0.0868 // Validation R2: 0.0392
# Epoch: 28 // Train loss: 0.0831 // Validation R2: 0.1535
# Epoch: 29 // Train loss: 0.086 // Validation R2: 0.1965
# Epoch: 30 // Train loss: 0.091 // Validation R2: 0.2053
# Epoch: 31 // Train loss: 0.0953 // Validation R2: 0.2018
# Epoch: 32 // Train loss: 0.0976 // Validation R2: 0.1973
# Epoch: 33 // Train loss: 0.0976 // Validation R2: 0.1977
# Epoch: 34 // Train loss: 0.0955 // Validation R2: 0.2034
# Epoch: 35 // Train loss: 0.0917 // Validation R2: 0.2122
# Epoch: 36 // Train loss: 0.0869 // Validation R2: 0.2203
# Epoch: 487 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 488 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 489 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 490 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 491 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 492 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 493 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 494 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 495 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 496 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 497 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 498 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 499 // Train loss: 0.0 // Validation R2: 0.9999
# Epoch: 500 // Train loss: 0.0 // Validation R2: 0.9999

# %% [markdown]
# # Set up hyperparameters for explanation pipeline

# %%
explanation_params = {
                        "seed": seed,
                        "interpret_samples": 20,
                        "epochs": 50,
                        "optimizer": "adam",
                        "lr": 0.01,
                        "lr_patience": 10,
                        "l1_lambda": 1e-4
                    }

# %% [markdown]
# # Explanation pipeline execution

# %% [markdown]
# # Case A

# %%
query_node = "1" # The central node is the node in position "10"
repeats = 10 # Number of initializations to be averaged for the pipeline
query_type = None

t1 = time.time()

# Define Explainer object
pipelineA = Explainer(
        features,
        edge_index,
        modelA.float(),
        explanation_params,
        node_names,
        communities,
        community_names,
        query_type,
        problem="node_prediction"
    )


# Run Explainer object
node_dfA, community_dfA = pipelineA.run(query_node, repeats)

print("Time ellapsed for explanation for node {}: {}sec".format(query_node,round(time.time() - t1, 4)))
# Out:
# Time ellapsed for explanation for node 1: 5.071sec

# %% [markdown]
# # Case B

# %%
query_node = "1" # The central node is the node in position "10"
repeats = 10 # Number of initializations to be averaged for the pipeline
query_type = None

t1 = time.time()

# Define Explainer object
pipelineB = Explainer(
        features,
        edge_index,
        modelB.float(),
        explanation_params,
        node_names,
        communities,
        community_names,
        query_type,
        problem="node_prediction"
    )


# Run Explainer object
node_dfB, community_dfB = pipelineB.run(query_node, repeats)

print("Time ellapsed for explanation for node {}: {}sec".format(query_node,round(time.time() - t1, 4)))
# Out:
# Time ellapsed for explanation for node 1: 4.9398sec

# %% [markdown]
# # Result checking

# %%
# Community ranking
community_dfA
# Out:
#          score
# name
# red   0.405105
# blue  0.357987

# %%
# Community ranking
community_dfB
# Out:
#          score
# name
# red   0.477715
# blue  0.357019

# %%
# Node ranking
node_dfA
# Out:
#       config_value_mean  config_value_std
# name
# 4              0.470924          0.231037
# 3              0.375919          0.277766
# 2              0.368474          0.253461
# 0              0.357987          0.184962
# 1              0.005563          0.008636

# %%
# Node ranking
node_dfB
# Out:
#       config_value_mean  config_value_std
# name
# 4              0.542254          0.317490
# 2              0.532268          0.199936
# 3              0.358622          0.220820
# 0              0.357019          0.162873
# 1             -0.005306          0.018591
